# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
arr = np.array([[1,2,np.nan], [np.nan,3,4]])

# %%
arr
# Out:
# array([[ 1.,  2., nan],
#        [nan,  3.,  4.]])

# %%
dframe1 = DataFrame(arr, index=['A','B'], columns=['One','Two','Three'])

# %%
dframe1
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe1.sum()
# Out:
# One      1.0
# Two      5.0
# Three    4.0
# dtype: float64

# %%
dframe1.sum(axis=1)
# Out:
# A    3.0
# B    7.0
# dtype: float64

# %%
dframe1.sum(axis=1)
# Out:
# A    3.0
# B    7.0
# dtype: float64

# %%
dframe1.min()
# Out:
# One      1.0
# Two      2.0
# Three    4.0
# dtype: float64

# %%
dframe1.idxmin()
# Out:
# One      A
# Two      A
# Three    B
# dtype: object

# %%
dframe1
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe1.cumsum()
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  5.0    4.0

# %%
dframe1.describe()
# Out:
#        One       Two  Three
# count  1.0  2.000000    1.0
# mean   1.0  2.500000    4.0
# std    NaN  0.707107    NaN
# min    1.0  2.000000    4.0
# 25%    1.0  2.250000    4.0
# 50%    1.0  2.500000    4.0
# 75%    1.0  2.750000    4.0
# max    1.0  3.000000    4.0

# %%
import pandas.io.data as pdweb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-8ffec29273a9> in <module>()
# ----> 1 import pandas.io.data as pdweb
#
# C:\python\WPy-3662\python-3.6.6.amd64\lib\site-packages\pandas\io\data.py in <module>()
#       1 raise ImportError(
# ----> 2     "The pandas.io.data module is moved to a separate package "
#       3     "(pandas-datareader). After installing the pandas-datareader package "
#       4     "(https://github.com/pydata/pandas-datareader), you can change "
#       5     "the import ``from pandas.io import data, wb`` to "
#
# ImportError: The pandas.io.data module is moved to a separate package (pandas-datareader). After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.

# %%
import pandas_datareader as pdweb

# %%
from pandas_datareader import data as pdweb

# %%
import pandas_datareader.data as pdweb

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like

# %%
import pandas_datareader.data as pdweb

# %%
import datetime

# %%
end = datetime.date.today()

# %%
start = end - datetime.timedelta(days = 1000)

# %%
pd_data = pdweb.DataReader('SNE','iex', start, end)
# Out:
# 5y

# %%
print(pd_data)
# Out:
#              open   high    low  close   volume
# date
# 2018-10-04  58.15  58.17  56.70  57.07  1836024
# 2018-10-05  57.75  57.91  56.79  57.23   775771
# 2018-10-08  56.90  57.33  56.45  57.07   937895
# 2018-10-09  57.81  58.23  57.78  57.97  1069696
# 2018-10-10  57.86  57.89  56.04  56.10  1611416
# 2018-10-11  55.99  56.62  55.20  55.52  1296795
# 2018-10-12  55.74  56.17  54.89  55.51  1412064

# %%
pd_data
# Out:
#                open     high      low    close   volume
# date
# 2016-01-19  22.3057  22.3646  21.5691  21.8146  2170198
# 2016-01-20  20.5181  20.9159  19.8011  20.6654  2711934
# 2016-01-21  20.5574  21.0976  20.4690  20.7833  1303007
# 2016-01-22  21.0190  21.5003  20.9896  21.3530  1689191
# 2016-01-25  20.8815  21.0780  20.7145  20.7538  1177753
# 2016-01-26  20.4690  20.9110  20.4297  20.8520  1078298
# 2016-01-27  20.8422  21.0485  20.5476  20.6654   739856
# 2016-01-28  19.8993  20.1252  19.5457  19.9288  2452752
# 2016-01-29  22.1682  24.0442  22.1093  23.4549  5517032
# 2016-02-01  22.8263  22.9147  22.5611  22.8950  1908670
# 2016-02-02  21.9619  22.2959  21.8441  21.9914  2828981
# 2016-02-03  21.6967  21.8146  21.1860  21.6378  1575338
# 2016-02-04  21.6575  21.9619  21.5101  21.6869   980710
# 2016-02-05  21.8539  21.8834  21.2940  21.3431  1225618
# 2016-02-08  21.0288  21.0735  20.4985  20.8226  1545240
# 2016-02-09  20.0663  20.4886  20.0466  20.3806  3052328
# ...

# %%
rets = pd_data.pct_change()

# %%
rets
# Out:
#                 open      high       low     close    volume
# date
# 2016-01-19       NaN       NaN       NaN       NaN       NaN
# 2016-01-20 -0.080141 -0.064776 -0.081969 -0.052680  0.249625
# 2016-01-21  0.001915  0.008687  0.033730  0.005705 -0.519528
# 2016-01-22  0.022454  0.019087  0.025434  0.027411  0.296379
# 2016-01-25 -0.006542 -0.019642 -0.013106 -0.028062 -0.302771
# 2016-01-26 -0.019754 -0.007923 -0.013749  0.004732 -0.084445
# 2016-01-27  0.018232  0.006575  0.005771 -0.008949 -0.313867
# 2016-01-28 -0.045240 -0.043865 -0.048760 -0.035644  2.315175
# 2016-01-29  0.114019  0.194731  0.131159  0.176935  1.249323
# 2016-02-01  0.029687 -0.046976  0.020435 -0.023871 -0.654040
# 2016-02-02 -0.037869 -0.027004 -0.031780 -0.039467  0.482174
# 2016-02-03 -0.012075 -0.021587 -0.030127 -0.016079 -0.443143
# 2016-02-04 -0.001807  0.006752  0.015298  0.002269 -0.377461
# 2016-02-05  0.009068 -0.003574 -0.010046 -0.015853  0.249725
# ...

# %%
# %matplotlib inline

# %%
pd_data.plot()

# %%
import datetime
import pandas_datareader.data as web
start = datetime.datetime(1970, 10,14)

# %%
end = datetime.datetime(2018,10,13)

# %%
nikkei225 = web.DataReader("NIKKEI225", "fred", start, end)

# %%
# %matplotlib inline

# %%
nikkei225.plot()

# %%
rets.corr()
# Out:
#             open      high       low     close    volume
# open    1.000000  0.870843  0.877807  0.753263  0.007683
# high    0.870843  1.000000  0.854571  0.895929  0.133511
# low     0.877807  0.854571  1.000000  0.897935 -0.115869
# close   0.753263  0.895929  0.897935  1.000000  0.003485
# volume  0.007683  0.133511 -0.115869  0.003485  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(rets.corr())

# %%
ser1 = Series(['w','w','x','y','z','w','a','a','z'])

# %%
ser1
# Out:
# 0    w
# 1    w
# 2    x
# 3    y
# 4    z
# 5    w
# 6    a
# 7    a
# 8    z
# dtype: object

# %%
ser1.unique()
# Out:
# array(['w', 'x', 'y', 'z', 'a'], dtype=object)

# %%
ser1.value_counts()
# Out:
# w    3
# a    2
# z    2
# x    1
# y    1
# dtype: int64
