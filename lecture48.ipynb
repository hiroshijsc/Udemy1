# %%
from numpy.random import randn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 5.,  3.,  9., 19., 24., 17., 12.,  6.,  3.,  2.]),
#  array([-2.3585701 , -1.86319456, -1.36781902, -0.87244348, -0.37706794,
#          0.11830761,  0.61368315,  1.10905869,  1.60443423,  2.09980977,
#          2.59518531]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([ 5.,  3.,  8., 10., 13., 12., 10., 12.,  5.,  2.]),
#  array([-2.26419404, -1.78504765, -1.30590125, -0.82675486, -0.34760846,
#          0.13153793,  0.61068432,  1.08983072,  1.56897711,  2.0481235 ,
#          2.5272699 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed = True)
# Out:
# C:\python\WPy-3662\python-3.6.6.amd64\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.10093353, 0.06056012, 0.18168035, 0.3835474 , 0.48448092,
#         0.34317399, 0.24224046, 0.12112023, 0.06056012, 0.04037341]),
#  array([-2.3585701 , -1.86319456, -1.36781902, -0.87244348, -0.37706794,
#          0.11830761,  0.61368315,  1.10905869,  1.60443423,  2.09980977,
#          2.59518531]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed = True, alpha = 0.5, bins = 20)
plt.hist(dataset2, normed = True, alpha = 0.5, bins = 20, color = 'indianred')
# Out:
# C:\python\WPy-3662\python-3.6.6.amd64\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\python\WPy-3662\python-3.6.6.amd64\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.10435224, 0.15652836, 0.        , 0.15652836, 0.10435224,
#         0.31305672, 0.20870448, 0.31305672, 0.31305672, 0.36523284,
#         0.31305672, 0.31305672, 0.20870448, 0.31305672, 0.31305672,
#         0.31305672, 0.15652836, 0.10435224, 0.        , 0.10435224]),
#  array([-2.26419404, -2.02462084, -1.78504765, -1.54547445, -1.30590125,
#         -1.06632806, -0.82675486, -0.58718166, -0.34760846, -0.10803527,
#          0.13153793,  0.37111113,  0.61068432,  0.85025752,  1.08983072,
#          1.32940391,  1.56897711,  1.80855031,  2.0481235 ,  2.2876967 ,
#          2.5272699 ]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind = 'hex')
